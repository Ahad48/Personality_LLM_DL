# %%
from ocean_datasets import retrieve_reddit_data
from ocean_utils import score_boxplots

train_df, valid_df, test_df = retrieve_reddit_data()
score_boxplots(data=train_df, filename='reddit_train_score_boxplots.png')
score_boxplots(data=valid_df, filename='reddit_valid_score_boxplots.png')
score_boxplots(data=test_df, filename='reddit_test_score_boxplots.png')

# %% [markdown]
# Class Imbalance

# %%
import pandas as pd
questions_df = pd.read_csv('datasets/gpt_roleplay_questions_v01.csv')
score_boxplots(data=questions_df, filename='gpt_roleplay_questions_score_boxplots.png')

answers_df = pd.read_csv('datasets/gpt_roleplay_answers_v01.csv')
score_boxplots(data=answers_df, filename='gpt_roleplay_answers_score_boxplots.png')

# %% [markdown]
# Tokenize Text Inputs
